# %% [markdown]
# # DSF-racket in Jupyter
#
# It might be convenient to use DSF-racket in a Jupyter notebook.
# If you [install the racket kernel](https://github.com/rmculpepper/iracket) this is easy.

# %% [markdown]
# First require the dsf modules. This notebook was edited with the `/dsf/` folder one directory up:

# %%
(require "../dsf/base.rkt" "../dsf/tree.rkt")

# %% [markdown]
# Now DSF formulas can be used just like in DrRacket and the images will be shown automatically.
#
# First, a simple example of oil mixed with gas:

# %%
(: o w)
# Out:
# (object:image% #f #f #f #f 1 1 0 (object:image-snipclass% #f "((lib \"image-core.ss\" \"mrlib\") (lib \"image-core-wxme.rkt\" \"mrlib\"))" 1) #1=(object:style% (object:color% 0 0 0 1.0 #f) (object:color% 255 255 255 1.0 #f) (object:font% 'aligned '#(12.0 default normal normal #f default #f aligned #0=#hash()) #f #f #f #f 'default 12.0 12.0 16.0 #f 'default 'normal #f #0# 'normal 1 '#(1 12.0 normal normal #f default #f aligned) (attrs-key #f #0#)) 'bottom 0.0 0.0 0.0 0.0 (object:style-list% '#<hash> #1# '(#1#) 1 #<procedure:add-member> '#hash() 0) "Basic" #f #f (object:style-delta% 'default #f 0 12 'normal 'base 'normal 'base 'default 'base #f #t #f #t #f #f 'bottom 'base (object:mult-color% 0 0 0 1.0) (object:mult-color% 0 0 0 1.0) (object:add-color% 0 0 0 0.0) (object:add-color% 255 255 255 0.0)) #t (object:pen% '#(0 0 0 1.0 0 solid round round) #t 0 #f (object:color% 0 0 0 1.0 #t) 'round 'round 'solid 0) (object:brush% '#(255 255 255 1.0 solid) (object:color% 255 255 255 1.0 #t) 'solid #t 0 #f #f #f #f) 0 '()) (overlay (translate 0 0 (translate 40 40 (ellipse 80 80 0 255 (color 220 220 0 200) #f))) (translate 88.0 0 (translate 40 40 (ellipse 80 80 0 255 (color 1 1 1 200) #f)))) (bb 168.0 80 80) #f #f #f #f #t)

# %% [markdown]
# Next, a more complex example.
#
# Here, there is oil mixed with a structure consisting of water overlapping gas.
#
# This is then enclosed in a solid container, which is itself enclosed in a solid container.
#
# Finally there is a solid located completely external to this complex structure.

# %%
(: s (@ (@ (: o (& w g)) S) S))
# Out:
# (object:image% #f #f #f #f 1 1 0 (object:image-snipclass% #f "((lib \"image-core.ss\" \"mrlib\") (lib \"image-core-wxme.rkt\" \"mrlib\"))" 1) #1=(object:style% (object:color% 0 0 0 1.0 #f) (object:color% 255 255 255 1.0 #f) (object:font% 'aligned '#(12.0 default normal normal #f default #f aligned #0=#hash()) #f #f #f #f 'default 12.0 12.0 16.0 #f 'default 'normal #f #0# 'normal 1 '#(1 12.0 normal normal #f default #f aligned) (attrs-key #f #0#)) 'bottom 0.0 0.0 0.0 0.0 (object:style-list% '#<hash> #1# '(#1#) 1 #<procedure:add-member> '#hash() 0) "Basic" #f #f (object:style-delta% 'default #f 0 12 'normal 'base 'normal 'base 'default 'base #f #t #f #t #f #f 'bottom 'base (object:mult-color% 0 0 0 1.0) (object:mult-color% 0 0 0 1.0) (object:add-color% 0 0 0 0.0) (object:add-color% 255 255 255 0.0)) #t (object:pen% '#(0 0 0 1.0 0 solid round round) #t 0 #f (object:color% 0 0 0 1.0 #t) 'round 'round 'solid 0) (object:brush% '#(255 255 255 1.0 solid) (object:color% 255 255 255 1.0 #t) 'solid #t 0 #f #f #f #f) 0 '()) (overlay (translate 0 20 (translate 40 40 (ellipse 80 80 0 255 (color 160 0 0 200) #f))) (translate 88.0 0 (overlay (translate 10.0 10 (overlay (translate 10.0 10 (overlay (translate 0 0 (translate 40 40 (ellipse 80 80 0 255 (color 220 220 0 200) #f))) (translate 88.0 0 (overlay (translate 0 0 (translate 40 40 (ellipse 80 80 0 255 (color 0 0 220 200) #f))) (translate 45 0 (translate 40 40 (ellipse 80 80 0 255 (color 1 1 1 200) #f))))))) (translate 0 0 (translate 0 0 (polygon (list (pulled-point 0 0 0 0 0 0) (pulled-point 0 0 233 0 0 0) (pulled-point 0 0 233 100 0 0) (pulled-point 0 0 0 100 0 0)) 255 #2=(color 120 0 0 150)))))) (translate 0 0 (translate 0 0 (polygon (list (pulled-point 0 0 0 0 0 0) (pulled-point 0 0 253 0 0 0) (pulled-point 0 0 253 120 0 0) (pulled-point 0 0 0 120 0 0)) 255 #2#)))))) (bb 341.0 120 120) #f #f #f #f #t)

# %% [markdown]
# It can be helpful to look at tree representations of these structures.
#
# To do this we define the structure as a list and store it in a variable.
#
# We can then use `draw-tree` to render a binary tree representation.

# %%
(define myStructure '(@ (: o w) S))

# %%
myStructure
# Out:
# '(@ (: o w) S)

# %%
(draw-tree myStructure)
# Out:
# (pict '(picture 250.0 250.0 (put 0.0 0.0 #137=(color "gray" #138=(picture 250.0 250.0 (put 0 0 #140=(picture 250.0 250.0 (put -0.0 0.0 (picture 250.0 250.0 (put 0.0 0.0 #141=(picture 250.0 250.0)) (put 0.0 0.0 (picture 250.0 250.0 (put 0 0 (picture 250.0 250.0)) (put 150.0 225.0 (line 75.0 -100.0 . #0=(#f))))))))) (put 0.0 0.0 #139=(picture 250.0 250.0))))) (put 0.0 0.0 #1=(picture 250.0 250.0 (put 0.0 0.0 #127=(color "gray" #128=(picture 250.0 250.0 (put 0 0 #130=(picture 250.0 250.0 (put -0.0 0.0 (picture 250.0 250.0 (put 0.0 0.0 #131=(picture 250.0 250.0)) (put 0.0 0.0 (picture 250.0 250.0 (put 0 0 (picture 250.0 250.0)) (put 150.0 225.0 (line -75.0 -100.0 . #0#)))))))) (put 0.0 0.0 #129=(picture 250.0 250.0))))) (put 0.0 0.0 #2=(picture 250.0 250.0 (put 0.0 0.0 #117=(color "gray" #118=(picture 250.0 250.0 (put 0 0 #120=(picture 250.0 250.0 (put -0.0 0.0 (picture 250.0 250.0 (put 0.0 0.0 #121=(picture 250.0 250.0)) (put 0.0 0.0 (picture 250.0 250.0 (put 0 0 (picture 250.0 250.0)) (put 75.0 125.0 (line 50.0 -100.0 . #0#)))))))) (put 0.0 0.0 #119=(picture 250.0 250.0))))) (put 0.0 0.0 #3=(picture 250.0 250.0 (put 0.0 0.0 #107=(color "gray" #108=(picture 250.0 250.0 (put 0 0 #110=(picture 250.0 250.0 (put -0.0 0.0 (picture 250.0 250.0 (put 0.0 0.0 #111=(picture 250.0 250.0)) (put 0.0 0.0 (picture 250.0 250.0 (put 0 0 (picture 250.0 250.0)) (put 75.0 125.0 (line -50.0 -100.0 . #0#)))))))) (put 0.0 0.0 #109=(picture 250.0 250.0))))) (put 0.0 0.0 #4=(picture 250.0 250.0 (put 0 0 #19=(picture 250.0 250.0 (put 100.0 200.0 #20=(picture 50.0 50.0)) (put 0.0 0 #26=(picture 250.0 150.0 (put 0 0.0 #27=(picture 150.0 150.0 (put 0 0 #42=(picture 150.0 150.0 (put 50.0 100.0 #43=(picture 50.0 50.0)) (put 0.0 0 #49=(picture 150.0 50.0 (put 0 0.0 #50=(picture 50.0 50.0 (put 0.0 0.0 #56=(picture 50.0 50.0)) (put 0.0 0.0 #51=(picture 50.0 50.0 (put 0.0 0.0 #52=(picture 50.0 50.0 (put 0.0 0.0 #54=(prog #<procedure:...t/private/utils.rkt:384:8> 50)) (put 21.5 18.015625 #53=(prog #<procedure:...ct/private/pict.rkt:1620:10> 13.96875)))))))) (put 100.0 0.0 #65=(picture 50.0 50.0 (put 0.0 0.0 #71=(picture 50.0 50.0)) (put 0.0 0.0 #66=(picture 50.0 50.0 (put 0.0 0.0 #67=(picture 50.0 50.0 (put 0.0 0.0 #69=(prog #<procedure:...t/private/utils.rkt:384:8> 50)) (put 20.0 18.015625 #68=(prog #<procedure:...ct/private/pict.rkt:1620:10> 13.96875)))))))))))) (put 50.0 100.0 #28=(picture 50.0 50.0 (put 0.0 0.0 #34=(picture 50.0 50.0 (put 0 0 #36=(picture 50.0 50.0)) (put 0.0 0.0 #35=(picture 50 50)))) (put 0.0 0.0 #29=(picture 50.0 50.0 (put 0.0 0.0 #30=(picture 50.0 50.0 (put 0.0 0.0 #32=(prog #<procedure:...t/private/utils.rkt:384:8> 50)) (put 23.0 18.015625 #31=(prog #<procedure:...ct/private/pict.rkt:1620:10> 13.96875)))))))))) (put 200.0 100.0 #86=(picture 50.0 50.0 (put 0.0 0.0 #92=(picture 50.0 50.0)) (put 0.0 0.0 #87=(picture 50.0 50.0 (put 0.0 0.0 #88=(picture 50.0 50.0 (put 0.0 0.0 #90=(prog #<procedure:...t/private/utils.rkt:384:8> 50)) (put 21.0 18.015625 #89=(prog #<procedure:...ct/private/pict.rkt:1620:10> 13.96875)))))))))))) (put 125.0 200.0 #5=(picture 50.0 50.0 (put 0.0 0.0 #11=(picture 50.0 50.0 (put 0 0 #13=(picture 50.0 50.0)) (put 0.0 0.0 #12=(picture 50 50)))) (put 0.0 0.0 #6=(picture 50.0 50.0 (put 0.0 0.0 #7=(picture 50.0 50.0 (put 0.0 0.0 #9=(prog #<procedure:...t/private/utils.rkt:384:8> 50)) (put 19.0 18.015625 #8=(prog #<procedure:...ct/private/pict.rkt:1620:10> 13.96875))))))))))))))))) 250.0 250.0 29.154296875 0.0 (list (child #142=(pict #1# 250.0 250.0 29.154296875 0.0 (list (child #132=(pict #2# 250.0 250.0 29.154296875 0.0 (list (child #122=(pict #3# 250.0 250.0 29.154296875 0.0 (list (child #112=(pict #4# 250.0 250.0 29.154296875 0.0 (list (child (pict #4# 250.0 250.0 29.154296875 0.0 (list (child (pict #5# 50.0 50.0 29.154296875 0.0 (list (child (pict #6# 50.0 50.0 29.154296875 0.0 (list (child #14=(pict #7# 50.0 50.0 29.154296875 0.0 (list (child (pict #8# 12.0 13.96875 11.138671875 2.830078125 '() (bbox 0 0 12.0 13.96875 2 ...

# %%
(define myComplicatedThing '(: s (@ (@ (: o (& w g)) S) S)))

# %%
myComplicatedThing
# Out:
# '(: s (@ (@ (: o (& w g)) S) S))

# %%
(draw-tree myComplicatedThing)
# Out:
# (pict '(picture 550.0 550.0 (put 0.0 0.0 #335=(color "gray" #336=(picture 550.0 550.0 (put 0 0 #338=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #339=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 221.875 525.0 (line 196.875 -100.0 . #0=(#f))))))))) (put 0.0 0.0 #337=(picture 550.0 550.0))))) (put 0.0 0.0 #1=(picture 550.0 550.0 (put 0.0 0.0 #325=(color "gray" #326=(picture 550.0 550.0 (put 0 0 #328=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #329=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 418.75 425.0 (line 106.25 -100.0 . #0#)))))))) (put 0.0 0.0 #327=(picture 550.0 550.0))))) (put 0.0 0.0 #2=(picture 550.0 550.0 (put 0.0 0.0 #315=(color "gray" #316=(picture 550.0 550.0 (put 0 0 #318=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #319=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 418.75 425.0 (line -106.25 -100.0 . #0#)))))))) (put 0.0 0.0 #317=(picture 550.0 550.0))))) (put 0.0 0.0 #3=(picture 550.0 550.0 (put 0.0 0.0 #305=(color "gray" #306=(picture 550.0 550.0 (put 0 0 #308=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #309=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 312.5 325.0 (line 112.5 -100.0 . #0#)))))))) (put 0.0 0.0 #307=(picture 550.0 550.0))))) (put 0.0 0.0 #4=(picture 550.0 550.0 (put 0.0 0.0 #295=(color "gray" #296=(picture 550.0 550.0 (put 0 0 #298=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #299=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 312.5 325.0 (line -112.5 -100.0 . #0#)))))))) (put 0.0 0.0 #297=(picture 550.0 550.0))))) (put 0.0 0.0 #5=(picture 550.0 550.0 (put 0.0 0.0 #285=(color "gray" #286=(picture 550.0 550.0 (put 0 0 #288=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #289=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 200.0 225.0 (line 75.0 -100.0 . #0#)))))))) (put 0.0 0.0 #287=(picture 550.0 550.0))))) (put 0.0 0.0 #6=(picture 550.0 550.0 (put 0.0 0.0 #275=(color "gray" #276=(picture 550.0 550.0 (put 0 0 #278=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #279=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 275.0 125.0 (line 50.0 -100.0 . #0#)))))))) (put 0.0 0.0 #277=(picture 550.0 550.0))))) (put 0.0 0.0 #7=(picture 550.0 550.0 (put 0.0 0.0 #265=(color "gray" #266=(picture 550.0 550.0 (put 0 0 #268=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #269=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 275.0 125.0 (line -50.0 -100.0 . #0#)))))))) (put 0.0 0.0 #267=(picture 550.0 550.0))))) (put 0.0 0.0 #8=(picture 550.0 550.0 (put 0.0 0.0 #255=(color "gray" #256=(picture 550.0 550.0 (put 0 0 #258=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #259=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 200.0 225.0 (line -75.0 -100.0 . #0#)))))))) (put 0.0 0.0 #257=(picture 550.0 550.0))))) (put 0.0 0.0 #9=(picture 550.0 550.0 (put 0.0 0.0 #245=(color "gray" #246=(picture 550.0 550.0 (put 0 0 #248=(picture 550.0 550.0 (put -0.0 0.0 (picture 550.0 550.0 (put 0.0 0.0 #249=(picture 550.0 550.0)) (put 0.0 0.0 (picture 550.0 550.0 (put 0 0 (picture 550.0 550.0)) (put 221.875 525.0 (line -196.875 -100.0 . #0#)))))))) (put 0.0 0.0 #247=(picture 550.0 550.0))))) (put 0.0 0.0 #10=(picture 550.0 550.0 (put 0 0 #25=(picture 550.0 550.0 (put 250.0 500.0 #26=(picture 50.0 50.0)) (put 0.0 0 #32=(picture 550.0 450.0 (put 0 400.0 #33=(picture 50.0 50.0 (put 0.0 0.0 #39=(picture 50.0 50.0)) (put 0.0 0.0 #34=(picture 50.0 50.0 (put 0.0 0.0 #35=(picture 50.0 50.0 (put 0.0 0.0 #37=(prog #<procedure:. ...
